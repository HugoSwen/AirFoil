# %%
from CST import CSTAirfoilParameterization
import pandas as pd
import numpy as np

# %% [markdown]
# > 8阶CST-LLM方法，没有复现LLM部分，直接使用原文中表现最好的特征函数: 0.5 ∗ x + 0.5 ∗ np.sign(x) ∗ np.abs(x) ∗∗ (1∕3)

# %%
cst = CSTAirfoilParameterization(order=8, N1=0.5, N2=1.0, t_func=lambda x: 0.5 * x + 0.5 * np.sign(x) * np.abs(x) ** (1/3))
# cst = CSTAirfoilParameterization(order=8, N1=0.5, N2=1.0)

# %%
data_dir = 'data'
files = ['param.csv', 'x_lower.csv', 'x_upper.csv', 'z_lower.csv', 'z_upper.csv']

# 读取翼型数据
param = pd.read_csv(f'{data_dir}/param.csv')
x_lower_ = pd.read_csv(f'{data_dir}/x_lower.csv', header=None).to_numpy()
x_upper_ = pd.read_csv(f'{data_dir}/x_upper.csv', header=None).to_numpy()
z_lower_ = pd.read_csv(f'{data_dir}/z_lower.csv', header=None).to_numpy()
z_upper_ = pd.read_csv(f'{data_dir}/z_upper.csv', header=None).to_numpy()

# %%
for i in range(1): 
    x_lower, z_lower, x_upper, z_upper = x_lower_[i][::-1], z_lower_[i][::-1], x_upper_[i], z_upper_[i]

    cst.fit_airfoil(x_upper, z_upper)
    cst.fit_airfoil(x_lower, z_lower, is_upper=False)

    z_upper_pred = cst.generate_airfoil(x_upper)
    z_lower_pred = cst.generate_airfoil(x_lower, is_upper=False)

    cst.plot_airfoil(x_upper, z_upper, x_lower, z_lower, z_upper_pred, z_lower_pred)
    cst.plot_residuals(x_upper, z_upper, x_lower, z_lower, z_upper_pred, z_lower_pred)

# %%
af = pd.read_csv(f'{data_dir}/e63.csv', header=None)
af_x = af.iloc[:, 0].to_numpy()
af_z = af.iloc[:, 1].to_numpy()

af_x_upper = af_x[:33][::-1]
af_z_upper = af_z[:33][::-1]
af_x_lower = af_x[33:]
af_z_lower = af_z[33:]

cst.fit_airfoil(af_x_upper, af_z_upper)
cst.fit_airfoil(af_x_lower, af_z_lower, is_upper=False)

af_z_upper_pred = cst.generate_airfoil(af_x_upper)
af_z_lower_pred = cst.generate_airfoil(af_x_lower, is_upper=False)

cst.plot_airfoil(af_x_upper, af_z_upper, af_x_lower, af_z_lower, af_z_upper_pred, af_z_lower_pred)
cst.plot_residuals(af_x_upper, af_z_upper, af_x_lower, af_z_lower, af_z_upper_pred, af_z_lower_pred)

# %%
af = pd.read_csv(f'{data_dir}/s1223.csv', header=None)
af_x = af.iloc[:, 0].to_numpy()
af_z = af.iloc[:, 1].to_numpy()

af_x_upper = af_x[:46][::-1]
af_z_upper = af_z[:46][::-1]
af_x_lower = af_x[46:]
af_z_lower = af_z[46:]

cst.fit_airfoil(af_x_upper, af_z_upper)
cst.fit_airfoil(af_x_lower, af_z_lower, is_upper=False)

af_z_upper_pred = cst.generate_airfoil(af_x_upper)
af_z_lower_pred = cst.generate_airfoil(af_x_lower, is_upper=False)

cst.plot_airfoil(af_x_upper, af_z_upper, af_x_lower, af_z_lower, af_z_upper_pred, af_z_lower_pred)
cst.plot_residuals(af_x_upper, af_z_upper, af_x_lower, af_z_lower, af_z_upper_pred, af_z_lower_pred)

# %%
af = pd.read_csv(f'{data_dir}/clarky.csv', header=None)
af_x = af.iloc[:, 0].to_numpy()
af_z = af.iloc[:, 1].to_numpy()

af_x_upper = af_x[:61]
af_z_upper = af_z[:61]
af_x_lower = af_x[61:]
af_z_lower = af_z[61:]

cst.fit_airfoil(af_x_upper, af_z_upper)
cst.fit_airfoil(af_x_lower, af_z_lower, is_upper=False)

af_z_upper_pred = cst.generate_airfoil(af_x_upper)
af_z_lower_pred = cst.generate_airfoil(af_x_lower, is_upper=False)

cst.plot_airfoil(af_x_upper, af_z_upper, af_x_lower, af_z_lower, af_z_upper_pred, af_z_lower_pred)
cst.plot_residuals(af_x_upper, af_z_upper, af_x_lower, af_z_lower, af_z_upper_pred, af_z_lower_pred)

# %%
af = pd.read_csv(f'{data_dir}/naca66215.csv', header=None)
af_x = af.iloc[:, 0].to_numpy()
af_z = af.iloc[:, 1].to_numpy()

af_x_upper = af_x[:26][::-1]
af_z_upper = af_z[:26][::-1]
af_x_lower = af_x[26:]
af_z_lower = af_z[26:]

cst.fit_airfoil(af_x_upper, af_z_upper)
cst.fit_airfoil(af_x_lower, af_z_lower, is_upper=False)

af_z_upper_pred = cst.generate_airfoil(af_x_upper)
af_z_lower_pred = cst.generate_airfoil(af_x_lower, is_upper=False)

cst.plot_airfoil(af_x_upper, af_z_upper, af_x_lower, af_z_lower, af_z_upper_pred, af_z_lower_pred)
cst.plot_residuals(af_x_upper, af_z_upper, af_x_lower, af_z_lower, af_z_upper_pred, af_z_lower_pred)

# %%
af = pd.read_csv(f'{data_dir}/rae5214.csv', header=None)
af_x = af.iloc[:, 0].to_numpy()
af_z = af.iloc[:, 1].to_numpy()

af_x_upper = af_x[:42]
af_z_upper = af_z[:42]
af_x_lower = af_x[42:]
af_z_lower = af_z[42:]

cst.fit_airfoil(af_x_upper, af_z_upper)
cst.fit_airfoil(af_x_lower, af_z_lower, is_upper=False)

af_z_upper_pred = cst.generate_airfoil(af_x_upper)
af_z_lower_pred = cst.generate_airfoil(af_x_lower, is_upper=False)

cst.plot_airfoil(af_x_upper, af_z_upper, af_x_lower, af_z_lower, af_z_upper_pred, af_z_lower_pred)
cst.plot_residuals(af_x_upper, af_z_upper, af_x_lower, af_z_lower, af_z_upper_pred, af_z_lower_pred)

# %%
import os
import openai
from feature_llm import LLMSymbolicRegression
from prompt import Initialize_prompt_A, Initialize_prompt_B, Initialize_prompt_C
from dotenv import load_dotenv
load_dotenv()

llm_sr = LLMSymbolicRegression()

prompt = Initialize_prompt_B

response = llm_sr.llm_query(prompt=prompt, model="Qwen/Qwen3-14B")

response
# Out:
# 'np.sin(np.pi * x)'
